# %% [markdown]
# python -m spacy download en_core_web_smData Generation
#
# Data was generated in 2 steps:
#
# 1.Initial Data was captured internally via Google Form which asked users for car issues they currently have or had in the past
# Classified that data into: brakes, starter, other
#
# 2.Took this 'training set' and used Markovify to generate more data for our tutorial

# %%
# !pip install -r requirements.txt
import pandas as pd
import csv
# Out:
# Collecting markovify
#   Downloading markovify-0.9.0.tar.gz (27 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 19.8 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-1.20.2-cp38-cp38-manylinux2010_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 110.1 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-1.2.3-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 95.2 MB/s eta 0:00:01
# Collecting pytest
#   Downloading pytest-6.2.3-py3-none-any.whl (280 kB)
#      |████████████████████████████████| 280 kB 118.3 MB/s eta 0:00:01
# Requirement already satisfied: regex in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2020.11.13)
# Collecting scipy
#   Downloading scipy-1.6.2-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
#      |████████████████████████████████| 27.2 MB 107.0 MB/s eta 0:00:01
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 116.3 MB/s eta 0:00:01
# Collecting spacy
#   Downloading spacy-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 40.1 MB/s eta 0:00:01
# Collecting tensorflow
#   Downloading tensorflow-2.4.1-cp38-cp38-manylinux2010_x86_64.whl (394.4 MB)
#      |████████████████████▊           | 255.0 MB 122.9 MB/s eta 0:00:02
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 394.4 MB 3.4 MB/s eta 0:00:01
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.11.0-py2.py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 121.3 MB/s eta 0:00:01
# Requirement already satisfied: wrapt in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (1.12.1)
# Collecting unidecode
#   Downloading Unidecode-1.2.0-py2.py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 125.6 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 118.2 MB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 116.5 MB/s eta 0:00:01
# Requirement already satisfied: six in /opt/app-root/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas->-r requirements.txt (line 4)) (2021.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/app-root/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: toml in /opt/app-root/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: attrs>=19.2.0 in /opt/app-root/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 5)) (20.3.0)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: packaging in /opt/app-root/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 5)) (20.9)
# Requirement already satisfied: py>=1.8.2 in /opt/app-root/lib/python3.8/site-packages (from pytest->-r requirements.txt (line 5)) (1.10.0)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/app-root/lib/python3.8/site-packages (from spacy->-r requirements.txt (line 9)) (2.25.1)
# Collecting srsly<3.0.0,>=2.4.0
#   Downloading srsly-2.4.0-cp38-cp38-manylinux2014_x86_64.whl (458 kB)
#      |████████████████████████████████| 458 kB 114.7 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.4.0-py3-none-any.whl (36 kB)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.3-cp38-cp38-manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 79.0 MB/s eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/app-root/lib/python3.8/site-packages (from spacy->-r requirements.txt (line 9)) (4.56.0)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from spacy->-r requirements.txt (line 9)) (54.0.0)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 108.2 MB/s eta 0:00:01
# Collecting thinc<8.1.0,>=8.0.2
#   Downloading thinc-8.0.2-cp38-cp38-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 111.7 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.8/site-packages (from spacy->-r requirements.txt (line 9)) (2.11.3)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 35.9 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.1
#   Downloading catalogue-2.0.1-py3-none-any.whl (9.6 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.0
#   Downloading spacy_legacy-3.0.2-py2.py3-none-any.whl (7.8 kB)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading smart_open-3.0.0.tar.gz (113 kB)
#      |████████████████████████████████| 113 kB 115.7 MB/s eta 0:00:01
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 9)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 9)) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy->-r requirements.txt (line 9)) (2020.12.5)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/app-root/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy->-r requirements.txt (line 9)) (7.1.2)
# Collecting numpy
#   Downloading numpy-1.19.5-cp38-cp38-manylinux2010_x86_64.whl (14.9 MB)
#      |████████████████████████████████| 14.9 MB 91.3 MB/s eta 0:00:01
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 97.9 MB/s  eta 0:00:01
# Requirement already satisfied: wheel~=0.35 in /opt/app-root/lib/python3.8/site-packages (from tensorflow->-r requirements.txt (line 10)) (0.36.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/app-root/lib/python3.8/site-packages (from tensorflow->-r requirements.txt (line 10)) (3.7.4.3)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp38-cp38-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 42.9 MB/s eta 0:00:01
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 97.4 MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 107.4 MB/s eta 0:00:01
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 56.2 MB/s eta 0:00:01
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.1.0)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 86.1 MB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.9.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow->-r requirements.txt (line 10)) (3.14.0)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 98.9 MB/s eta 0:00:01
# Collecting absl-py~=0.10
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 122.7 MB/s eta 0:00:01
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 121.9 MB/s eta 0:00:01
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (1.25.0)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 111.9 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 107.9 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (4.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (4.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/app-root/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow->-r requirements.txt (line 10)) (3.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/app-root/lib/python3.8/site-packages (from jinja2->spacy->-r requirements.txt (line 9)) (1.1.1)
# Building wheels for collected packages: markovify, smart-open
#   Building wheel for markovify (setup.py) ... done
#   Created wheel for markovify: filename=markovify-0.9.0-py3-none-any.whl size=18476 sha256=6941ed4dc84f973b7f36972ad871d706d04e76ebfc834f382d4a8beaf93934f6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_3lxdrk5/wheels/cf/19/41/0f8707b2305726fadbd92649dcdb28d98a04e159eb24dd72f0
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-3.0.0-py3-none-any.whl size=107097 sha256=90a5cf5c4a81a8a707a41856d6f1eac131cd674ca390cbbc2d57f9ecf4d47664
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_3lxdrk5/wheels/11/73/9a/f91ac1f1816436b16423617c5be5db048697ff152a9c4346f2
# Successfully built markovify smart-open
# Installing collected packages: numpy, murmurhash, cymem, catalogue, werkzeug, wasabi, typer, tensorboard-plugin-wit, srsly, smart-open, pydantic, preshed, pillow, markdown, kiwisolver, grpcio, google-auth-oauthlib, cycler, blis, absl-py, unidecode, thinc, tensorflow-estimator, tensorboard, spacy-legacy, scipy, pathy, pandas, opt-einsum, matplotlib, keras-preprocessing, iniconfig, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow-hub, tensorflow, spacy, seaborn, pytest, markovify
# Successfully installed absl-py-0.12.0 astunparse-1.6.3 blis-0.7.4 catalogue-2.0.1 cycler-0.10.0 cymem-2.0.5 flatbuffers-1.12 gast-0.3.3 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 iniconfig-1.1.1 keras-preprocessing-1.1.2 kiwisolver-1.3.1 markdown-3.3.4 markovify-0.9.0 matplotlib-3.4.1 murmurhash-1.0.5 numpy-1.19.5 opt-einsum-3.3.0 pandas-1.2.3 pathy-0.4.0 pillow-8.2.0 preshed-3.0.5 pydantic-1.7.3 pytest-6.2.3 scipy-1.6.2 seaborn-0.11.1 smart-open-3.0.0 spacy-3.0.5 spacy-legacy-3.0.2 srsly-2.4.0 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0 tensorflow-hub-0.11.0 thinc-8.0.2 typer-0.3.2 unidecode-1.2.0 wasabi-0.8.2 werkzeug-1.0.1

# %%
df = pd.read_csv('response.csv') 
df = df.fillna('')
df['response']=df.iloc[:,3]+df.iloc[:,5]+df.iloc[:,6]
df['issue'] = df.iloc[:,1]
df['symptom'] = df.iloc[:,2] + df.iloc[:,4]
subset = df.iloc[:,-3:]
subset
# Out:
#                                               response    issue  \
# 0    my brakes make a squeaking noise whenever I tr...   Brakes
# 1    super frustrating every time I start my car it...  Starter
# 2                 I can't open the damn door to my car    Other
# 3                   I turn the key and nothing happens  Starter
# 4    Car doesn't always start when it's low on blin...  Starter
# ..                                                 ...      ...
# 104         Parking brake doesn’t return once released   Brakes
# 105                              my lights do not work    Other
# 106  I try to start the engine only to find that th...  Starter
# 107  The driver side window auto function does not ...    Other
# 108  Car takes too long to stop when I press the br...   Brakes
#
#                                    symptom
# 0                 Car makes grinding noise
# 1                    Car starts then stops
# 2
# 3                        Car doesn't start
# 4                        Car doesn't start
# ..                                     ...
# 104  Car brakes, but then brakes disengage
# 105
# 106                      Car doesn't start
# 107
# 108      Car doesn't stop in timely manner
#
# [109 rows x 3 columns]

# %%
import markovify
import codecs

# %%
#markovify is a simple, extensible Markov chain generator
#Its primary use is for building Markov models of large corpora of text and generating random sentences from that.


#Function builds the model according to what issue (e.g. brakes, starter, other) is given
def train_markov_type(data, issue):
    return markovify.Text(data[data["issue"] == issue].response, retain_original=False, state_size=2)

#Function takes one of the 'issue' models and creates a randomly-generated sentence of length up to 200 characters.  Note only creates '1' sentence
def make_sentence(model, length=100):
    return model.make_short_sentence(length, max_overlap_ratio = .7, max_overlap_total=15)

#built models
other_model = train_markov_type(subset, "Other")
brakes_model = train_markov_type(subset, "Brakes")
starter_model = train_markov_type(subset, "Starter")

# %% [markdown]
# We can combine these models with relative weights

# %%
#import numpy

def generate_cases(models, weights=None):
    if weights is None:
        weights = [1] * len(models)
    
    choices = [] # Array of tuples of weight and models
    
    total_weight = float(sum(weights))
    
    for i in range(len(weights)):
        choices.append((float(sum(weights[0:i+1])) / total_weight, models[i]))
    
    # Return a tuple of model and category that are randomly selected by given weights.
    def choose_model():
        r = numpy.random.uniform()
        for (model_weight, model) in choices:
            if r <= model_weight:
                return model
        return choices[-1][1]


    while True:
        local_model = choose_model() 
        # local_model[0]) is the markovify model, local_model[1] is the category
        yield make_sentence(local_model[0]), local_model[1]

# %%
import numpy

#Generate new sentences & classify them

generated_cases = generate_cases([(other_model,'other'), (brakes_model,'brakes'), (starter_model,'starter')], [14,7,7])

# Tuples with sentence and category
sentence_tuples = [next(generated_cases)  for i in range(200)]  # create 100 sentence/category tuples

# Write to csv file
with open('testdata1.csv', 'w') as file:
    writer = csv.writer(file, delimiter=',', lineterminator='\n')
    writer.writerows(sentence_tuples)
